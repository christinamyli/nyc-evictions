# %%
import pandas as pd

# %%
ls
# Out:
# Evictions_20240717.csv
# Lede Project 2 Crashes.ipynb
# Motor_Vehicle_Collisions_-_Crashes.csv
# Motor_Vehicle_Collisions_-_Crashes_20240713.csv
# Motor_Vehicle_Collisions_-_Person_20240715.csv
# NPS - CY2007-Present Mortality Data.csv
# NPS-Mortality-Data-Released-April-2024.xlsx
# OLD/
# Open_Streets_Locations.csv
# accidents_data_cleaning.ipynb
# accidents_data_visualization.ipynb
# data/
# gis_1/
# pc_crash_17_df.csv
# pc_crash_21_df.csv
# pc_crash_23_df.csv
# project-2 TEST.ipynb

# %%
evict_df = pd.read_csv("Evictions_20240717.csv")
evict_df
# Out:
#       Court Index Number  Docket Number        Eviction Address  \
# 0               53902/20            5240      394 MONTGOMERY ST
# 1             60545/17-2           22454          3607 BROADWAY
# 2               11632/20          362052      2515 GRAND AVENUE
# 3               25472/18          101137       10 RICHMAN PLAZA
# 4              321284/23           17830        133-38 228TH ST
# ...                  ...             ...                    ...
# 93901         B318469/22          105686     946 COLLEGE AVENUE
# 93902           58728/16          331974  3416 KINGSLAND AVENUE
# 93903           61480/17            3445  315 EAST 187TH STREET
# 93904          K99183/17           85522        4001 7TH AVENUE
# 93905          303726/21          173727          57 WEST 76 ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            4D    11/29/2023              David
# ...

# %%
evict_df['Executed Date'] = pd.to_datetime(evict_df['Executed Date'])
evict_df
# Out:
#       Court Index Number  Docket Number        Eviction Address  \
# 0               53902/20            5240      394 MONTGOMERY ST
# 1             60545/17-2           22454          3607 BROADWAY
# 2               11632/20          362052      2515 GRAND AVENUE
# 3               25472/18          101137       10 RICHMAN PLAZA
# 4              321284/23           17830        133-38 228TH ST
# ...                  ...             ...                    ...
# 93901         B318469/22          105686     946 COLLEGE AVENUE
# 93902           58728/16          331974  3416 KINGSLAND AVENUE
# 93903           61480/17            3445  315 EAST 187TH STREET
# 93904          K99183/17           85522        4001 7TH AVENUE
# 93905          303726/21          173727          57 WEST 76 ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            4D    2023-11-29              David
# ...

# %%
evict_df['Year'] = evict_df['Executed Date'].dt.year
evict_df
# Out:
#       Court Index Number  Docket Number        Eviction Address  \
# 0               53902/20            5240      394 MONTGOMERY ST
# 1             60545/17-2           22454          3607 BROADWAY
# 2               11632/20          362052      2515 GRAND AVENUE
# 3               25472/18          101137       10 RICHMAN PLAZA
# 4              321284/23           17830        133-38 228TH ST
# ...                  ...             ...                    ...
# 93901         B318469/22          105686     946 COLLEGE AVENUE
# 93902           58728/16          331974  3416 KINGSLAND AVENUE
# 93903           61480/17            3445  315 EAST 187TH STREET
# 93904          K99183/17           85522        4001 7TH AVENUE
# 93905          303726/21          173727          57 WEST 76 ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            4D    2023-11-29              David
# ...

# %%
evict_df = evict_df[evict_df['Year'] < 2024]
evict_df
# Out:
#       Court Index Number  Docket Number        Eviction Address  \
# 0               53902/20            5240      394 MONTGOMERY ST
# 1             60545/17-2           22454          3607 BROADWAY
# 2               11632/20          362052      2515 GRAND AVENUE
# 3               25472/18          101137       10 RICHMAN PLAZA
# 5               56716/18           89943      540 EAST 169TH ST
# ...                  ...             ...                    ...
# 93901         B318469/22          105686     946 COLLEGE AVENUE
# 93902           58728/16          331974  3416 KINGSLAND AVENUE
# 93903           61480/17            3445  315 EAST 187TH STREET
# 93904          K99183/17           85522        4001 7TH AVENUE
# 93905          303726/21          173727          57 WEST 76 ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            4D    2023-11-29              David
# ...

# %%
evict_df['Council District'].value_counts().head(4)
# Out:
# Council District
# 15.0    4573
# 17.0    3910
# 16.0    3594
# 14.0    3576
# Name: count, dtype: int64

# %%
evict_df['Council District'].value_counts().head(4).sum()
# Out:
# 15653

# %%
15653 / len(evict_df)
# Out:
# 0.1835655314757482

# %%
evict_df['Year'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
bx_evict_df = evict_df[evict_df['BOROUGH'] == 'BRONX']
bx_evict_df.head(30)
# Out:
#    Court Index Number  Docket Number   \
# 2            11632/20          362052
# 3            25472/18          101137
# 5            56716/18           89943
# 8            70741/17           76301
# 9           58786/17A          476270
# 11         B045509/16          374956
# 14           20165/18           18406
# 16           47374/17           90320
# 19         B071301/17          390147
# 20             B62/19          112301
# 21          300459/22          364344
# 22          321439/22          362496
# 30          327907/22          112507
# 34          B19364/18          107326
# 37          37693/17B           68582
# 47         B005426/19          403483
# 48         B900083/18           86284
# 52           36121/17           69864
# 54           30272/18           85090
# 55         B018243/18          398657
# 62           36423/18          483818
# 67           B5585/20          103489
# 69           41913/18           87564
# ...

# %%
bx_evict_df['Year'].value_counts().sort_index()
# Out:
# Year
# 2017    7658
# 2018    7140
# 2019    6244
# 2020    1088
# 2021      29
# 2022    1175
# 2023    4320
# Name: count, dtype: int64

# %%
bx_evict_df['Year'].value_counts().sum()
# Out:
# 27654

# %%
bk_evict_df = evict_df[evict_df['BOROUGH'] == 'BROOKLYN']
bk_evict_df
# Out:
#       Court Index Number  Docket Number   \
# 0               53902/20            5240
# 7              302512/22           15297
# 12             K51959/18          104488
# 18            83052/17-1          295492
# 25              95249/18           10267
# ...                  ...             ...
# 93890           54689/18           24730
# 93892          305042/23            6159
# 93893         54799/17-2          201966
# 93899          K53088/17           81132
# 93904          K99183/17           85522
#
#                                         Eviction Address  \
# 0                                      394 MONTGOMERY ST
# 7                   4824 CHURCH AVENUE GR. FLOOR STORE 3
# 12                                 2775 EAST 16TH STREET
# 18                                       4515 SNYDER AVE
# 25     (VENUS KNITTING MILLS) 117 GRATTAN ST - SUITE ...
# ...                                                  ...
# 93890                                774 ROCKAWAY AVENUE
# ...

# %%
bk_evict_df['Year'].value_counts().sort_index()
# Out:
# Year
# 2017    6355
# 2018    6157
# 2019    5312
# 2020    1005
# 2021     100
# 2022    1871
# 2023    3928
# Name: count, dtype: int64

# %%
bk_evict_df['Year'].value_counts().sum()
# Out:
# 24728

# %%
mn_evict_df = evict_df[evict_df['BOROUGH'] == 'MANHATTAN']
mn_evict_df
# Out:
#       Court Index Number  Docket Number                Eviction Address  \
# 1             60545/17-2           22454                  3607 BROADWAY
# 23              66115/19           99963                 601 W 184TH ST
# 42              79421/18          107445                  2508 BROADWAY
# 44              51007/17            7330           510 WEST 52ND STREET
# 45              60852/18          482658              321 W 47TH STREET
# ...                  ...             ...                            ...
# 93872          252630/15           64603              225 EAST 118TH ST
# 93878           56737/17          468135                   4 RIVER ROAD
# 93885           50784/18            7612       22 WEST 32ND ST - 9TH FL
# 93897          310327/22           18248  173 EAST 101ST STREET APT. 29
# 93905          303726/21          173727                  57 WEST 76 ST
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# ...

# %%
mn_evict_df['Year'].value_counts().sort_index()
# Out:
# Year
# 2017    3450
# 2018    3390
# 2019    2818
# 2020     521
# 2021      68
# 2022     934
# 2023    2614
# Name: count, dtype: int64

# %%
mn_evict_df['Year'].value_counts().sum()
# Out:
# 13795

# %%
qs_evict_df = evict_df[evict_df['BOROUGH'] == 'QUEENS']
qs_evict_df
# Out:
#       Court Index Number  Docket Number   \
# 6               64313/17           12542
# 15              66469/19           25488
# 17            Q077517/17          388586
# 24              56561/17            5629
# 35              61960/17          202465
# ...                  ...             ...
# 93847           52616/18           23648
# 93854           63129/17          112116
# 93860         Q57981/17B           80577
# 93871           64085/19           25838
# 93900          062866/17          153796
#
#                                         Eviction Address  \
# 6                                      30-24 23RD STREET
# 15     95-13/15/17 NORTHERN BLVD A/K/A 32-56 96TH STREET
# 17                                 130 BEACH 59TH STREET
# 24                                 178-31 107 AVE APT #2
# 35                                      51-45 ALMEDA AVE
# ...                                                  ...
# 93847                                  41-80 FRAME PLACE
# ...

# %%
qs_evict_df['Year'].value_counts().sort_index()
# Out:
# Year
# 2017    4325
# 2018    4452
# 2019    3705
# 2020     696
# 2021      36
# 2022     813
# 2023    2022
# Name: count, dtype: int64

# %%
qs_evict_df['Year'].value_counts().sum()
# Out:
# 16049

# %%
si_evict_df = evict_df[evict_df['BOROUGH'] == 'STATEN ISLAND']
si_evict_df
# Out:
#       Court Index Number  Docket Number         Eviction Address  \
# 38              52356/16          149968       35 HOLLAND AVENUE
# 65              52036/17          152885       85 HOLLAND AVENUE
# 86            R52253/18B          100265  1611 CASTLETON AVENU E
# 89              53099/19           78483        477 GENESEE AVE.
# 114            52197/18R           86424       149 KELVIN AVENUE
# ...                  ...             ...                     ...
# 93705          R50366/19           95628       44 WANDELL AVENUE
# 93723         52456/17-2            6385         424 LISK AVENUE
# 93781           52258/17           76477       180 PARKHILL AVE.
# 93825           50626/20          111843      253 LOCKMAN AVENUE
# 93827          300072/21           78818     4864 ARTHUR KILL RD
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 38                          11A    2017-01-11             Ronald
# ...

# %%
si_evict_df['Year'].value_counts().sort_index()
# Out:
# Year
# 2017    734
# 2018    691
# 2019    636
# 2020    112
# 2021     35
# 2022    274
# 2023    564
# Name: count, dtype: int64

# %%
si_evict_df['Year'].value_counts().sum()
# Out:
# 3046

# %%
evict_df.groupby('BOROUGH')['Residential/Commercial'].value_counts()
# Out:
# BOROUGH        Residential/Commercial
# BRONX          Residential               26258
#                Commercial                 1396
# BROOKLYN       Residential               22536
#                Commercial                 2192
# MANHATTAN      Residential               11169
#                Commercial                 2626
# QUEENS         Residential               14392
#                Commercial                 1657
# STATEN ISLAND  Residential                2852
#                Commercial                  194
# Name: count, dtype: int64

# %%
evict_2017_df = evict_df[evict_df['Year'] == 2017]
evict_2017_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 15.0    1317
# 14.0    1087
# 17.0    1021
# 16.0     984
# 41.0     743
# Name: count, dtype: int64

# %%
evict_2017_df.to_csv("evict_2017_df.csv")

# %%
evict_2018_df = evict_df[evict_df['Year'] == 2018]
evict_2018_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 15.0    1153
# 17.0    1080
# 16.0     947
# 14.0     902
# 41.0     704
# Name: count, dtype: int64

# %%
evict_2018_df.to_csv("evict_2018_df.csv")

# %%
evict_2019_df = evict_df[evict_df['Year'] == 2019]
evict_2019_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 15.0    952
# 17.0    916
# 16.0    865
# 14.0    700
# 42.0    674
# Name: count, dtype: int64

# %%
evict_2019_df.to_csv("evict_2019_df.csv")

# %%
evict_2020_df = evict_df[evict_df['Year'] == 2020]
evict_2020_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 16.0    170
# 15.0    160
# 17.0    157
# 14.0    146
# 12.0    111
# Name: count, dtype: int64

# %%
evict_2020_df.to_csv("evict_2020_df.csv")

# %%
evict_2021_df = evict_df[evict_df['Year'] == 2021]
evict_2021_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 49.0    23
# 3.0     15
# 1.0     12
# 36.0    12
# 29.0     9
# Name: count, dtype: int64

# %%
evict_2021_df.to_csv("evict_2021_df.csv")

# %%
evict_2022_df = evict_df[evict_df['Year'] == 2022]
evict_2022_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 15.0    186
# 41.0    179
# 40.0    154
# 42.0    151
# 49.0    150
# Name: count, dtype: int64

# %%
evict_2022_df.to_csv("evict_2022_df.csv")

# %%
evict_2023_df = evict_df[evict_df['Year'] == 2023]
evict_2023_df['Council District'].value_counts().head(5)
# Out:
# Council District
# 15.0    798
# 17.0    599
# 14.0    591
# 16.0    501
# 8.0     485
# Name: count, dtype: int64

# %%
evict_2023_df.to_csv("evict_2023_df.csv")

# %%
evict_2023_df
# Out:
#       Court Index Number  Docket Number   \
# 0               53902/20            5240
# 2               11632/20          362052
# 7              302512/22           15297
# 21             300459/22          364344
# 22             321439/22          362496
# ...                  ...             ...
# 93881           50830/22          115888
# 93892          305042/23            6159
# 93897          310327/22           18248
# 93901         B318469/22          105686
# 93905          303726/21          173727
#
#                            Eviction Address Eviction Apartment Number  \
# 0                         394 MONTGOMERY ST                        4D
# 2                         2515 GRAND AVENUE                 3RD FLOOR
# 7      4824 CHURCH AVENUE GR. FLOOR STORE 3                       NaN
# 21                     1050 ANDERSON AVENUE                       2-G
# 22                      3215 HOLLAND AVENUE                        E7
# ...
